# %% [markdown]
# <a href="https://colab.research.google.com/github/juancho0809/Design-Software/blob/main/Workshop1/code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Vehicles
#
# First we make the classes that helps ud to maintain the code more organize

# %%
class Engine:

  def __init__(self, name: str, type_of_engine: str, potency: int, weight: int):
    self.name = name
    self.type_of_engine = type_of_engine
    self.potency =potency
    self.weight = weight

class Vehicle(Engine):

  def __init__(self, name: str, type_of_engine: str, potency: int, weight: int,chasis: str ,model: str ,gas_consumption: int,year: int):
    super().__init__(name, type_of_engine, potency, weight)
    self.name = name
    self.type_of_engine = type_of_engine
    self.potency = potency
    self.weight = weight
    self.chasis = chasis
    self.model = model
    self.gas_consumption = gas_consumption
    self.year = year


class Car(Vehicle):
  def __init__(self, name: str, type_of_engine: str, potency: float, weight: float,chasis: str ,model: str ,gas_consumption: float,year: int,color:str,wheels:int):
    super().__init__(name, type_of_engine, potency, weight, chasis , model , gas_consumption, year)

    self.color = color
    self.wheels = wheels



class Truck(Vehicle):
  def __init__(self, name: str, type_of_engine: str, potency: float, weight: float,chasis: str ,model: str ,gas_consumption: float,year: int,color:str,wheels:int):
    super().__init__(name, type_of_engine, potency, weight, chasis , model , gas_consumption, year)

class Yacht(Vehicle):
  def __init__(self, name: str, type_of_engine: str, potency: float, weight: float,chasis: str ,model: str ,gas_consumption: float,year: int,color:str,wheels:int):
    super().__init__(name, type_of_engine, potency, weight, chasis , model , gas_consumption, year)

class Motorcycle(Vehicle):
  def __init__(self, name: str, type_of_engine: str, potency:float, weight: float,chasis: str ,model: str ,gas_consumption: float,year: int,color:str,wheels:int):
    super().__init__(name, type_of_engine, potency, weight, chasis , model , gas_consumption, year)


Menu = """

Option 1. Create car
Option 2. Create Truck
Option 3. Create Yacht
Option 4. Create Motorcycle
-------------------------------
Option 8. Exit

"""
"""
Select the vehicle who you want to meausure the gas consume
"""

print(Menu)
option = int(input("Press an option:"))
while option != 8:
  if option == 1:
    print("Car")
    x = 0
    car_ = Car(input("Name:"),input("Type of motor"),float(input("Potency:")),float(input("weight")),input("chasis"),input("model"),(1.1*car_.potency + 0.2*car_.weight - x),input("Year"),input("Color:"),input("Wheels:"))
    print("Ingresado")
    if car_.chasis == 'A':
      x = 0.3
    elif car_.chasis == 'B':
      x = 0.5
    car_.gas_consumption = car_.gas_consumption - x
    print("Ingresado")
    print(car_.name)
    print(car_.gas_consumption)

  elif option == 2:
    print("Truck")
    x = 0
    truck_ = Truck(input("Name:"),input("Type of motor"),float(input("Potency:")),float(input("weight")),input("chasis"),input("model"),(1.1*car_.potency + 0.2*car_.weight - x),input("Year"),input("Color:"),input("Wheels:"))
    print("Ingresado")
    if truck_.chasis == 'A':
      x = 0.3
    elif truck_.chasis == 'B':
      x = 0.5
    truck_.gas_consumption = truck_.gas_consumption - x
    print("Ingresado")
    print(truck_.name)
    print(truck_.gas_consumption)

  elif option == 3:
    print("Yacht")

    x = 0
    yacht_ = Yacht(input("Name:"),input("Type of motor"),float(input("Potency:")),float(input("weight")),input("chasis"),input("model"),(1.1*car_.potency + 0.2*car_.weight - x),input("Year"),input("Color:"),input("Wheels:"))
    print("Ingresado")
    if yacht_.chasis == 'A':
      x = 0.3
    elif yacht_.chasis == 'B':
      x = 0.5
    yacht_.gas_consumption = yacht_.gas_consumption - x
    print("Ingresado")
    print(yacht_.name)
    print(yacht_.gas_consumption)

  elif option == 4:
    print("Motorcycle")

    x = 0
    motorcycle_ = Motorcycle(input("Name:"),input("Type of motor"),float(input("Potency:")),float(input("weight")),input("chasis"),input("model"),(1.1*car_.potency + 0.2*car_.weight - x),input("Year"),input("Color:"),input("Wheels:"))
    print("Ingresado")
    if motorcycle_.chasis == 'A':
      x = 0.3
    elif motorcycle_.chasis == 'B':
      x = 0.5
    motorcycle_.gas_consumption = motorcycle_.gas_consumption - x
    print("Ingresado")
    print(motorcycle_.name)
    print(motorcycle_.gas_consumption)
  else:
    print("Option Invalid")
  print(Menu)
  option = int(input("Ingrese una opcion"))

# %%
class Car(Vehicle):
  def __init__(self, name: str, type_of_engine: str, potency: int, weight: int,chasis: str ,model: str ,gas_consumption: float,year: int,color:str,wheels:int):
    super().__init__(name, type_of_engine, potency, weight, chasis , model , gas_consumption, year)
    self.color = color
    self.wheels = wheels

  def calculate_gas_consumption(self):
        if self.chasis == 'A':
            x = 0.3
        elif self.chasis == 'B':
            x = 0.5
        else:
            x = 0
